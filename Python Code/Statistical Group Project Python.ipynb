# %% [markdown]
# # Statistical  - Group Project

# %% [markdown]
# ###### Group members :
# - Angorro Fajartri
# - Alipour Motlagh Mohammad Hadi
# - Harling Jeanne

# %% [markdown]
# ### Importing data and libraries

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandasql import sqldf
import seaborn as sns
import matplotlib.patches as mpatches

# %%
# Import banking data

# Importing train data
train = pd.read_csv('./Data/bank_mkt_train.csv')

# Importing test data 
test= pd.read_csv('./Data/bank_mkt_test.csv')

# %% [markdown]
# ### Data Cleaning

# %%
train.head()
# Out:
#    client_id   age         job  marital          education  default  housing  \
# 0      29925  42.0  management  married           basic.9y       no       no
# 1      37529  35.0  unemployed  married  university.degree       no      yes
# 2       2757  44.0  technician  married           basic.9y       no      yes
# 3       9642  45.0    services  married        high.school       no      yes
# 4      14183  45.0     unknown  married            unknown  unknown  unknown
#
#       loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0       no   cellular   jul  ...      1.0  999.0       0.0  nonexistent
# 1       no  telephone   jun  ...      4.0  999.0       0.0  nonexistent
# 2      yes   cellular   may  ...      1.0  999.0       0.0  nonexistent
# 3       no   cellular   apr  ...      1.0  999.0       0.0  nonexistent
# 4  unknown  telephone   may  ...      1.0  999.0       0.0  nonexistent
#
# ...

# %%
# Quickly handle missing value (if na)
train.isna().sum()
# Out:
# client_id           0
# age               202
# job               161
# marital           199
# education         170
# default           214
# housing           195
# loan              219
# contact           217
# month             199
# day_of_week       185
# campaign          203
# pdays             185
# previous          209
# poutcome          175
# emp.var.rate      165
# cons.price.idx    181
# cons.conf.idx     197
# euribor3m         204
# nr.employed       184
# subscribe           0
# dtype: int64

# %%
# Quickly check the type of the variables

train.dtypes
# Out:
# client_id           int64
# age               float64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# subscribe           int64
# dtype: object
